# %%
d={"jan":100,"march":2500}
type(d)
# Out:
# dict

# %%
d={"jan":{100:"possible"},"march":{2500}}
d['jan']
d['march']
# Out:
# {2500}

# %%
d={"jan":100,"feb":[200,300]}
# Out:
#   File "/tmp/ipykernel_1335/2731883519.py", line 2
#     d.get("jan":1000)
#                ^
# SyntaxError: invalid syntax

# %%
d.get("jan2500",10000) #if the key is not present returns default value
# Out:
# 10000

# %%
d.items()                                                #shows the keys and value
# Out:
# dict_items([('jan', 100), ('feb', [200, 300])])

# %%
d.values()                                           #shows values
# Out:
# dict_values([100, [200, 300]])

# %%
d.keys()                                            #shows keys
# Out:
# dict_keys(['jan', 'feb'])

# %%
d
# Out:
# {}

# %%
d={"jan":100,"march":2500}
x=d
x["jan"]=40000                                      #effect the value both values changes
print(x,d)
# Out:
# {'jan': 40000, 'march': 2500} {'jan': 40000, 'march': 2500}

# %%
d={"jan":100,"march":2500}
x=d.copy()
x["jan"]=25                                        #doesnt effect the value of first one keeps constant and second changes as updated
print(x)
print(d)
# Out:
# {'jan': 25, 'march': 2500}
# {'jan': 100, 'march': 2500}

# %%
months=["jan","feb","aug"]
x=dict.fromkeys(months,[1700,25,50])            #creating a dictonary of keys and values
print(x)
# Out:
# {'jan': [1700, 25, 50], 'feb': [1700, 25, 50], 'aug': [1700, 25, 50]}

# %%
d={"jan":100,"feb":2500}             #shows default if the value doesnt key doesnt present there it shows as default value
d.setdefault("jan25",25006)
# Out:
# 25006

# %%
d={"jan":100,"feb":2500}         #it compares the key fro the code f comes first than j
min(d)
# Out:
# 'feb'

# %%
len(d)           #counts the pairs of key value
# Out:
# 2

# %%
max(d)                    #max
# Out:
# 'jan'

# %%
x=[1,2,45]
y=[25,60,120]
print(min(x),min(y))         #min and max shown as per given
print(max(x),max(y))
# Out:
# 1 25
# 45 120
