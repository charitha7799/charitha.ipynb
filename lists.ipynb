# %%
bank = [ [
            [ ["C101", "Rahul", "Savings", 85000],
              ["C102", "Anita", "Current", 150000],
               ["C103", "Kiran", "Loan", 500000]
            ],

          [ ["C104", "Sneha", "Savings", 95000],
            ["C105", "Vikram", "Current", 275000],
            ["C106", "Meena", "Loan", 750000]

          ]
        ],

        [
           [["C201", "Arjun", "Savings", 120000],
            ["C202", "Pooja", "Current", 325000],
            ["C203", "Ramesh", "Loan", 900000]],

          [["C204", "Priya", "Savings", 45000],
           ["C205", "Amit", "Current", 185000],
           ["C206", "Divya", "Loan", 650000]]
        ],
        [

          [["C301", "Nikhil", "Savings", 78000],
           ["C302", "Kavya", "Current", 240000],
           ["C303", "Suresh", "Loan", 1000000]],
         [ ["C304", "Neha", "Savings", 135000],
           ["C305", "Rohan", "Current", 410000],
           ["C306", "Asha", "Loan", 550000]]
        ]
  ]

# %%
# Print Rahul's complete record.
bank[0][0][0]
# Out:
# ['C101', 'Rahul', 'Savings', 85000]

# %%
# Print Anita's account type.
bank[0][0][1][2]
# Out:
# 'Current'

# %%
# Print Kiran's loan amount.
bank[0][0][2][3]
# Out:
# 500000

# %%
# Print Sneha's customer ID.
bank[0][1][0][0]
# Out:
# 'C104'

# %%
# Print Vikram's balance
bank[0][1][1][3]
# Out:
# 275000

# %%
# Print Meena's complete record.
bank[0][1][2]
# Out:
# ['C106', 'Meena', 'Loan', 750000]

# %%
# Print Arjun's customer ID.
bank[1][0][0][0]
# Out:
# 'C201'

# %%
# Print Pooja's name.
bank[1][0][1][1]
# Out:
# 'Pooja'

# %%
# Print Ramesh's account type.
bank[1][0][2][2]
# Out:
# 'Loan'

# %%
# Print Priya's balance
bank[1][1][0][3]
# Out:
# 45000

# %%
# Print Amit's account type
bank[1][1][1][2]
# Out:
# 'Current'

# %%
# Print Divya's customer ID.
bank[1][1][2][0]
# Out:
# 'C206'

# %%
# Print Nikhil's account type.
bank[2][0][0][2]
# Out:
# 'Savings'

# %%
# Print Kavya's balance.
bank[2][0][1][3]
# Out:
# 240000

# %%
# Print Suresh's loan amount.
bank[2][0][2][3]
# Out:
# 1000000

# %%
# Print Neha's name.
bank[2][1][0][1]
# Out:
# 'Neha'

# %%
# Print Rohan's complete record.
bank[2][1][1]
# Out:
# ['C305', 'Rohan', 'Current', 410000]

# %%
# Print Asha's account type.
bank[2][1][2][2]
# Out:
# 'Loan'

# %%
# Print all customers in Bank 1, Branch 1.
bank[0][0]
# Out:
# [['C101', 'Rahul', 'Savings', 85000],
#  ['C102', 'Anita', 'Current', 150000],
#  ['C103', 'Kiran', 'Loan', 500000]]

# %%
# print all customers in Bank 1, Branch 2.
bank[0][1]
# Out:
# [['C104', 'Sneha', 'Savings', 95000],
#  ['C105', 'Vikram', 'Current', 275000],
#  ['C106', 'Meena', 'Loan', 750000]]

# %%
# Print all customers in Bank 2, Branch 1.
print(bank[1][0][0][1])
print(bank[1][0][1][1])
print(bank[1][0][2][1])
# Out:
# Arjun
# Pooja
# Ramesh

# %%
# Print all customers in Bank 2, Branch 2
print(bank[1][1][0][1])
print(bank[1][1][1][1])
print(bank[1][1][2][1])
# Out:
# Priya
# Amit
# Divya

# %%
# Print all customers in Bank 3, Branch 1.
print(bank[2][0][0][1])
print(bank[2][0][1][1])
print(bank[2][0][2][1])
# Out:
# Nikhil
# Kavya
# Suresh

# %%
# Print all customers in Bank 3, Branch 2.
print(bank[2][1][0][1])
print(bank[2][1][1][1])
print(bank[2][1][2][1])
# Out:
# Neha
# Rohan
# Asha

# %%
# Print all branches of Bank 1.
bank[0][0]
bank[0][1]
# Out:
# [['C104', 'Sneha', 'Savings', 95000],
#  ['C105', 'Vikram', 'Current', 275000],
#  ['C106', 'Meena', 'Loan', 750000]]

# %%
# Print all branches of Bank 2.
bank[1][0]
bank[1][1]
# Out:
# [['C204', 'Priya', 'Savings', 45000],
#  ['C205', 'Amit', 'Current', 185000],
#  ['C206', 'Divya', 'Loan', 650000]]

# %%
# Print all branches of Bank 3.
bank[2][0]
bank[2][1]
# Out:
# [['C304', 'Neha', 'Savings', 135000],
#  ['C305', 'Rohan', 'Current', 410000],
#  ['C306', 'Asha', 'Loan', 550000]]

# %%
# Print the first customer from every bank's first branch.
print(bank[0][0][0][1])
print(bank[1][0][0][1])
print(bank[2][0][0][1])
# Out:
# Rahul
# Arjun
# Nikhil

# %%
# Print the second customer from every bank's second branch.
print(bank[0][0][1][1])
print(bank[1][0][1][1])
print(bank[2][0][1][1])
# Out:
# Anita
# Pooja
# Kavya

# %%
# Print the loan amount of the last customer in Bank 3, Branch 2
print(bank[2][1][2][3])
# Out:
# 550000

# %% [markdown]
# List operations

# %%
# Create a list of 5 employee names and add a new employee using append()
emply=["ajay","arjun","akash","anand"]
emply.append("vijay")
print(emply)
# Out:
# ['ajay', 'arjun', 'akash', 'anand', 'vijay']

# %%
# Create a list of account numbers and add three new account numbers using extend().
acc_num=["101","102","103"]
acc_num.extend(["104","105","106"])
print(acc_num)
# Out:
# ['101', '102', '103', '104', '105', '106']

# %%
# Insert a new customer at the beginning of a customer list using insert().
cust_list=["a","b","c"]
cust_list.insert(0,"z")
print(cust_list)
# Out:
# ['z', 'a', 'b', 'c']

# %%
# Remove the last item from a list using pop().
fruits=["apple","banana","cherry"]
fruits.pop()
print(fruits)
# Out:
# ['apple', 'banana']

# %%
# Remove the customer "Rahul" from a customer list using remove()
cust_list=["ajay","rahul","vijay"]
cust_list.remove("rahul")
print(cust_list)
# Out:
# ['ajay', 'vijay']

# %%
# Count how many times the account type "Savings" appears in a list using count()
acc_type=["savings","current","loan","savings"]
acc_type.count("savings")
# Out:
# 2

# %%
# Find the index of "Current" in a list of account types using index().
acc_type=["savings","current","loan","savings"]
acc_type.index("current")
# Out:
# 1

# %%
# Reverse a list of transaction IDs using reverse().
trans_id=["101","102","103"]
trans_id.reverse()
print(trans_id)
# Out:
# ['103', '102', '101']

# %%
# Sort a list of account balances in ascending order using sort().
acc_bal=["8000","250","0","3000"]
acc_bal.sort()
print(acc_bal)
# Out:
# ['0', '250', '3000', '8000']

# %%
# Sort a list of customer names in descending order using sort().
cust_list=["arun","vijay","kaushik","rohith"]
cust_list.sort(reverse=True)
print(cust_list)
# Out:
# ['vijay', 'rohith', 'kaushik', 'arun']

# %%
# Make a copy of a list using copy() and verify that modifying the copied list does not affect the original list
list=["a","b","c"]
list_copy=list.copy()
list_copy.append("d")
print(list)
print(list_copy)
# Out:
# ['a', 'b', 'c']
# ['a', 'b', 'c', 'd']

# %%
# Clear all elements from a list using clear().
list=["a","b","c"]
list.clear()
print(list)
# Out:
# []

# %%
# Append a nested list containing a new customer's details to an existing customer list.
cust_list=["a","b","c"]
cust_list.append(["d","e"])
print(cust_list)
# Out:
# ['a', 'b', 'c', ['d', 'e']]

# %%
# Extend a list of branch names with another list of new branches.
branch_names=["alpha","beta","gamma","delta"]
branch_names.extend(["epsilon","zeta"])
print(branch_names)
# Out:
# ['alpha', 'beta', 'gamma', 'delta', 'epsilon', 'zeta']

# %%
# Remove the first occurrence of the balance 50000 from a list.
acc_bal= [1000,2500,5000,30000,5000]
acc_bal.remove(5000)
print(acc_bal)
# Out:
# [1000, 2500, 30000, 5000]

# %%
# Pop the element at index 2 from a list and print the removed value.
x=["a","b","c","d"]
removedvalue=x.pop(1)
print(removedvalue)
# Out:
# b

# %%
# Count how many times the city "Bangalore" appears in a list.
cities=("chennai","banglore","banglore","hydrebad","banglore")
cities.count("banglore")
# Out:
# 3

# %%
# Reverse a list of bank names and print the result.
bank_names=["hdfc","union","sbi","axis"]
bank_names.reverse()
print (bank_names)
# Out:
# ['axis', 'sbi', 'union', 'hdfc']

# %%
# Create a list of loan amounts and sort it in descending order.
loan_amount=["10000","25000","35000","450000"]
loan_amount.sort(reverse=True)
print(loan_amount)
# Out:
# ['450000', '35000', '25000', '10000']

# %% [markdown]
# sample tests
#
# customers = {"Rahul", "Anita", "Kiran", "Sneha", "Vikram"}
#
# new_customers = {"Amit", "Priya", "Rahul", "Divya"}
#
# loan_customers = {"Rahul", "Kiran", "Asha", "Ramesh"}
#
# savings_customers = {"Rahul", "Sneha", "Priya", "Nikhil"}
#
# transaction_ids = {101, 102, 103, 104, 105}
#
# balances = {85000, 120000, 45000, 95000, 275000}
#
# cities = {"Bangalore", "Hyderabad", "Chennai", "Pune"}
#
# new_cities = {"Mumbai", "Bangalore", "Delhi"}
#
# account_types = {"Savings", "Current", "Loan"}

# %%
#Print the customers set.
customers = {"Rahul", "Anita", "Kiran", "Sneha", "Vikram"}
print(customers)
# Out:
# {'Rahul', 'Anita', 'Vikram', 'Sneha', 'Kiran'}

# %%
#Find the number of elements in the customers set.
customers = {"Rahul", "Anita", "Kiran", "Sneha", "Vikram"}
len(customers)
# Out:
# 5

# %%
#Check whether "Rahul" exists in the customers set.
customers = {"Rahul", "Anita", "Kiran", "Sneha", "Vikram"}
print("Rahul" in customers)
# Out:
# True

# %%
#Check whether "Meena" exists in the customers set.
customers = {"Rahul", "Anita", "Kiran", "Sneha", "Vikram"}
print("menna"in customers)
# Out:
# False

# %%
#Iterate through all elements in the bank_branches set.
bank_branches = {"MG Road", "Indiranagar", "Whitefield", "Electronic City"}
for branch in bank_branches:
  print(branch)
# Out:
# Electronic City
# Whitefield
# Indiranagar
# MG Road

# %%
#Add "Meena" to the customers set.
customers = {"Rahul", "Anita", "Kiran", "Sneha", "Vikram"}
customers.add("meena")
print(customers)
# Out:
# {'Rahul', 'Anita', 'Vikram', 'Sneha', 'meena', 'Kiran'}

# %%
#Add "Mysore" to the cities set.
cities = {"Bangalore", "Hyderabad", "Chennai", "Pune"}
cities.add("mysore")
print(cities)
# Out:
# {'Bangalore', 'Hyderabad', 'mysore', 'Pune', 'Chennai'}

# %% [markdown]
# update

# %%
#Update the customers set with new_customers.
customers = {"Rahul", "Anita", "Kiran", "Sneha", "Vikram"}
new_customers = {"Amit", "Priya", "Rahul", "Divya"}
customers.update(new_customers)
print(customers)
# Out:
# {'Divya', 'Sneha', 'Priya', 'Kiran', 'Rahul', 'Anita', 'Amit', 'Vikram'}

# %%
#Update the cities set with new_cities.
cities = {"Bangalore", "Hyderabad", "Chennai", "Pune"}
new_cities={"mumbai","ladak"}
cities.update(new_cities)
print(cities)
# Out:
# {'Pune', 'ladak', 'Bangalore', 'mumbai', 'Hyderabad', 'Chennai'}

# %% [markdown]
# remove()

# %%
#Remove "Rahul" from the customers set.
customers = {"Rahul", "Anita", "Kiran", "Sneha", "Vikram"}
customers.remove("Rahul")
print(customers)
# Out:
# {'Anita', 'Vikram', 'Sneha', 'Kiran'}

# %%
#Remove "Pune" from the cities set.
cities = {"Bangalore", "Hyderabad", "Chennai", "Pune"}
cities.remove("Pune")
print(cities)
# Out:
# {'Hyderabad', 'Bangalore', 'Chennai'}

# %% [markdown]
# Discard()

# %%
#Discard "Anita" from the customers set.
customers = {"Rahul", "Anita", "Kiran", "Sneha", "Vikram"}
customers.discard("Anita")
print(customers)
# Out:
# {'Rahul', 'Vikram', 'Sneha', 'Kiran'}

# %%
#Discard "Delhi" from the cities set.
cities = {"Bangalore", "Hyderabad", "Chennai", "Pune"}
cities.discard("Delhi")
print(cities)
# Out:
# {'Hyderabad', 'Pune', 'Bangalore', 'Chennai'}

# %%
#Discard "Kolkata" from the cities set.
cities = {"Bangalore", "Hyderabad", "Chennai", "Pune"}
cities.discard("Kolkata")
print(cities)
# Out:
# {'Hyderabad', 'Pune', 'Bangalore', 'Chennai'}

# %% [markdown]
# pop

# %%
#Remove a random element from the transaction_ids set using pop().
transaction_ids = {101, 102, 103, 104, 105}
transaction_ids.pop()
print(transaction_ids)
# Out:
# {102, 103, 104, 105}

# %%
#Remove another random element from the account_types set.
account_types = {"Savings", "Current", "Loan"}
account_types.pop()
print(account_types)
# Out:
# {'Loan', 'Current'}

# %% [markdown]
# clear()

# %%
#Remove all elements from the balances set.
balances = {85000, 120000, 45000, 95000, 275000}
balances.clear()
print(balances)
# Out:
# set()

# %% [markdown]
# copy()

# %%
#Create a copy of the customers set.
customers = {"Rahul", "Anita", "Kiran", "Sneha", "Vikram"}
customers_copy=customers.copy()
print(customers_copy)
# Out:
# {'Rahul', 'Anita', 'Vikram', 'Sneha', 'Kiran'}

# %%
#Modify the copied set and verify that the original set remains unchanged.
customers = {"Rahul", "Anita", "Kiran", "Sneha", "Vikram"}
customers_copy=customers.copy()
customers_copy.add("meena")
print(customers_copy)
print(customers)
# Out:
# {'Rahul', 'Anita', 'Vikram', 'Sneha', 'meena', 'Kiran'}
# {'Rahul', 'Anita', 'Vikram', 'Sneha', 'Kiran'}

# %% [markdown]
# union()

# %%
#Find the union of customers and new_customers.
customers = {"Rahul", "Anita", "Kiran", "Sneha", "Vikram"}
new_customers = {"Amit", "Priya", "Rahul", "Divya"}
customers.union(new_customers)
# Out:
# {'Amit', 'Anita', 'Divya', 'Kiran', 'Priya', 'Rahul', 'Sneha', 'Vikram'}

# %%
#intersection()

# %%
#Find the common customers between customers and new_customers.
customers = {"Rahul", "Anita", "Kiran", "Sneha", "Vikram"}
new_customers = {"Amit", "Priya", "Rahul", "Divya"}
customers.intersection(new_customers)
# Out:
# {'Rahul'}

# %% [markdown]
# diffrence()

# %%
customers = {"Rahul", "Anita", "Kiran", "Sneha", "Vikram"}
new_customers = {"Amit", "Priya", "Rahul", "Divya"}
print(customers.difference(new_customers))
# Out:
# {'Sneha', 'Vikram', 'Anita', 'Kiran'}

# %%
loan_customers = {"Rahul", "Kiran", "Asha", "Ramesh"}
savings_customers = {"Rahul", "Sneha", "Priya", "Nikhil"}
print(savings_customers.difference(loan_customers))
# Out:
# {'Sneha', 'Priya', 'Nikhil'}

# %% [markdown]
# symmeteric_differences()

# %%
customers = {"Rahul", "Anita", "Kiran", "Sneha", "Vikram"}
new_customers = {"Amit", "Priya", "Rahul", "Divya"}
print(customers.symmetric_difference(new_customers))
# Out:
# {'Divya', 'Sneha', 'Priya', 'Kiran', 'Anita', 'Amit', 'Vikram'}

# %%
loan_customers = {"Rahul", "Kiran", "Asha", "Ramesh"}
print({"Rahul", "Kiran"}.issubset(loan_customers))
# Out:
# True

# %% [markdown]
# issuperset()

# %%
customers = {"Rahul", "Anita", "Kiran", "Sneha", "Vikram"}
new_customers = {"Amit", "Priya", "Rahul", "Divya"}
print(customers.issuperset({"Rahul", "Anita"}))
# Out:
# True

# %% [markdown]
# isdisjiont()

# %%
loan_customers = {"Rahul", "Kiran", "Asha", "Ramesh"}
new_customers = {"Amit", "Priya", "Rahul", "Divya"}
print(loan_customers.isdisjoint(new_cities))
# Out:
# True

# %% [markdown]
# miscellaneous()

# %%
balances = {85000, 120000, 45000, 95000, 275000}
print(max(balances))
# Out:
# 275000

# %%
balances = {85000, 120000, 45000, 95000, 275000}
print(min(balances))
# Out:
# 45000

# %%
balances = {85000, 120000, 45000, 95000, 275000}
print(sum(balances))
# Out:
# 620000

# %%
balances = {85000, 120000, 45000, 95000, 275000}
print(sorted(balances))
# Out:
# [45000, 85000, 95000, 120000, 275000]

# %%
customers = {"Rahul", "Anita", "Kiran", "Sneha", "Vikram"}
new_customers = {"Amit", "Priya", "Rahul", "Divya"}
customers_list =  (customers)
print(customers_list)
# Out:
# {'Rahul', 'Anita', 'Vikram', 'Sneha', 'Kiran'}

# %%
customers = {"Rahul", "Anita", "Kiran", "Sneha", "Vikram"}
new_customers = {"Amit", "Priya", "Rahul", "Divya"}
cities_tuple = tuple(customers)
print(cities_tuple)
# Out:
# ('Rahul', 'Anita', 'Vikram', 'Sneha', 'Kiran')

# %%
customers = {"Rahul", "Anita", "Kiran", "Sneha", "Vikram"}
new_customers = {"Amit", "Priya", "Rahul", "Divya"}
names_list = ["Rahul","Rahul","anita","sneha","sneha"]
unique_names = set(names_list)
print(unique_names)
# Out:
# {'Rahul', 'sneha', 'anita'}

# %%
employees = set()
print(employees)
# Out:
# set()

# %%
employees = set()

employees.add("maya")
employees.add("rajesh")
employees.add("jana")
employees.add("janai")
employees.add("kani")

print(employees)
# Out:
# {'jana', 'kani', 'janai', 'rajesh', 'maya'}

# %%
account_types = {"Savings", "Current", "Loan"}
print(len(account_types))
# Out:
# 3

# %%
loan_customers = {"Rahul", "Kiran", "Asha", "Ramesh"}
for c in loan_customers:
    print(c)
# Out:
# Rahul
# Kiran
# Asha
# Ramesh

# %%
transvction_ids = {101,102,103,104,105}
transaction_ids.clear()
print("transaction_ids after clear:", transaction_ids)
print("Is transaction_ids empty?", len(transaction_ids) == 0)
# Out:
# transaction_ids after clear: set()
# Is transaction_ids empty? True
